# %%
from householder_vector import calculate_householder_vector


x = [3,5]
v = calculate_householder_vector(x)
#plot x va v o matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot([0, x[0]], [0, x[1]], 'b', label='x')
plt.plot([0, v[0]], [0, v[1]], 'r', label='v')
plt.legend(loc='upper right')
y = x - 2 * np.dot(v, x) * v
plt.plot([0, y[0]], [0, y[1]], 'g', label='y')
